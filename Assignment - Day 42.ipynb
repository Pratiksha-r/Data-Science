# %%
# Load the data set petrol_consumption.csv.

# Use Decision Tree and Random Forest algorithms to predict Petrol_Consumption

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv("/content/petrol_consumption.csv")

# %%
data.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410

# %%
data.isnull().sum()
# Out:
# Petrol_tax                      0
# Average_income                  0
# Paved_Highways                  0
# Population_Driver_licence(%)    0
# Petrol_Consumption              0
# dtype: int64

# %%
data.describe()
# Out:
#        Petrol_tax  Average_income  Paved_Highways  \
# count   48.000000       48.000000       48.000000
# mean     7.668333     4241.833333     5565.416667
# std      0.950770      573.623768     3491.507166
# min      5.000000     3063.000000      431.000000
# 25%      7.000000     3739.000000     3110.250000
# 50%      7.500000     4298.000000     4735.500000
# 75%      8.125000     4578.750000     7156.000000
# max     10.000000     5342.000000    17782.000000
#
#        Population_Driver_licence(%)  Petrol_Consumption
# count                     48.000000           48.000000
# mean                       0.570333          576.770833
# std                        0.055470          111.885816
# min                        0.451000          344.000000
# 25%                        0.529750          509.500000
# 50%                        0.564500          568.500000
# 75%                        0.595250          632.750000
# max                        0.724000          968.000000

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
fig,axes=plt.subplots(1,5, figsize=(10,5))
count=0
for i in data.columns:
  sns.histplot(data[i], kde=True, ax=axes[count])
  count+=1
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)


fig,axes=plt.subplots(1,5, figsize=(10,5))
count=0
for i in range(len(data.columns)):
  sns.histplot(x[i], kde=True, ax=axes[count])
  count+=1

# %%
from sklearn import model_selection
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error,root_mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

x_train,x_test, y_train, y_test=train_test_split(x,y, test_size=0.25)

# %%
RF=RandomForestRegressor()
RF.fit(x,y)
y_pred=RF.predict(x_test)

# %%
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
print('Accurcy : ', r2_score(y_test,y_pred))
# Out:
# Mean Absolute Error: 9.880000000000004
# Mean Squared Error: 141.60716666666698
# Root Mean Squared Error: 11.899880951785484
# Accurcy :  0.9638677855821502
